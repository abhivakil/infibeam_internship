# %%
import gzip
import json

# %%
log_filename = "tracking.log-20220306-1646506021.gz"

# %%
d = {
    'logs': []
}

with gzip.open("logs/tracking.log-20220306-1646506021.gz", "rb") as f:
    for line in f:
        d['logs'].append(json.loads(line.decode('utf-8')))

print(json.dumps(d, indent=2))
# Out:
# {
#   "logs": [
#     {
#       "username": "",
#       "event_type": "/GponForm/diag_Form",
#       "ip": "172.16.30.152",
#       "agent": "curl/7.3.2",
#       "host": "192.168.0.1:443",
#       "referer": "",
#       "accept_language": "",
#       "event": "{\"POST\": {}, \"GET\": {\"style/\": [\"\"]}}",
#       "event_source": "server",
#       "context": {
#         "user_id": null,
#         "org_id": "",
#         "course_id": "",
#         "path": "/GponForm/diag_Form"
#       },
#       "time": "2022-03-02T21:47:53.000368+00:00",
#       "page": null
#     },
#     {
#       "username": "",
#       "event_type": "/",
#       "ip": "172.16.30.152",
#       "agent": "",
#       "host": "103.138.234.228:443",
#       "referer": "",
#       "accept_language": "",
#       "event": "{\"POST\": {}, \"GET\": {}}",
#       "event_source": "server",
#       "context": {
#         "user_id": null,
#         "org_id": "",
#         "course_id": "",
#         "path": "/"
#       },
# ...

# %%
print(d['logs'][232])
# Out:
# {'username': 'tania_penny', 'event_source': 'browser', 'name': 'edx.ui.lms.link_clicked', 'accept_language': 'en-US,en;q=0.9', 'time': '2022-03-03T07:34:59.342031+00:00', 'agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36', 'page': 'https://edumaxx.live/courses/course-v1:edumaxx+M0003+SPRING_2021_2022/courseware/c4edd278d17a4ca68030a2c2c562ec20/ad40bbe3a8ac43799b4b3af0de593baa/?child=first', 'host': 'edumaxx.live', 'session': 'f9779e4d4773eb3d5c52d966a12f41ae', 'referer': 'https://edumaxx.live/courses/course-v1:edumaxx+M0003+SPRING_2021_2022/courseware/c4edd278d17a4ca68030a2c2c562ec20/ad40bbe3a8ac43799b4b3af0de593baa/?child=first', 'context': {'user_id': 185, 'org_id': 'edumaxx', 'course_id': 'course-v1:edumaxx+M0003+SPRING_2021_2022', 'path': '/event'}, 'ip': '172.16.30.152', 'event': '{"target_url": "https://edumaxx.live/courses/course-v1:edumaxx+M0003+SPRING_2021_2022/course/", "current_url": "https://eduma
# ...

# %%
other_events = set()
event_types_indoc = set()

events_startswith = ['/courses/', '/user_api/v1/account/registration']

for log in d['logs']:
    if(log['event_type'].find('/') == -1):
        event_types_indoc.add(log['event_type'])
    elif(log['event_type'].startswith(tuple(events_startswith))):
        event_types_indoc.add(log['event_type'])
    else:
        other_events.add(log['event_type'])

event_types_indoc
# Out:
# {'/courses/course-v1:edumaxx+CED5612+FALL_2021-2022/about',
#  '/courses/course-v1:edumaxx+EAP0002+SPRING_2021_2022/about',
#  '/courses/course-v1:edumaxx+EAP0004+SUMMER_2021_2022/about',
#  '/courses/course-v1:edumaxx+EAP0005+SPRING_2021_2022/about',
#  '/courses/course-v1:edumaxx+EAP0006+FALL_2022_2023/about',
#  '/courses/course-v1:edumaxx+EAP0008+FALL_2021_2022/about',
#  '/courses/course-v1:edumaxx+EAP0009+FALL_2021_2022/about',
#  '/courses/course-v1:edumaxx+EDEMP001+EMPREENDEDORISMO/about',
#  '/courses/course-v1:edumaxx+EDUDJ001+DESENVOLVIMENTOJOGOSEDUMAXX/about',
#  '/courses/course-v1:edumaxx+FF0001+Summer_2021-2022/about',
#  '/courses/course-v1:edumaxx+M0002+FALL_2021_2022/about',
#  '/courses/course-v1:edumaxx+M0003+FALL_2021_2022/about',
#  '/courses/course-v1:edumaxx+M0003+SPRING_2021_2022/about',
#  '/courses/course-v1:edumaxx+M0003+SPRING_2021_2022/course/',
# ...

# %%
other_events
# Out:
# {'/',
#  '/%C0.%C0.\\%C0.%C0.\\%C0.%C0.\\boot.ini',
#  '/+CSCOT+/translation-table',
#  '/..\\..\\..\\..\\\\..\\..\\\\..\\..\\\\\\boot.ini',
#  '/..\\..\\..\\boot.ini',
#  '/..\\..\\\\..\\..\\\\..\\..\\\\..\\..\\boot.ini',
#  '/..\\/..\\/..\\/boot.ini',
#  '/..\\/\\..\\/\\..\\/\\boot.ini',
#  '/./RestAPI/LogonCustomization',
#  '/.aws/credentials',
#  '/.bash_history',
#  '/.build.sh',
#  '/.circleci/config.yml',
#  '/.circleci/ssh-config',
#  '/.env',
#  '/.git/HEAD',
#  '/.git/config',
#  '/.jenkins.sh',
#  '/.ksh_history',
#  '/.sh_history',
#  '/.ssh/known_hosts',
#  '/.ssh/known_hosts.old',
#  '/.travis.sh',
#  '/.well-known/acme-challenge/<?xml version="1.0"?><x:script xmlns:x="http://www.w3.org/1999/xhtml">alert(document.domain&#x29;</x:script>',
#  '/.well-known/acme-challenge/A1UYH37ZX4lioyJ1k7mloToGLUXt7k-P9D-KxNOCCe8',
#  '/.well-known/acme-challenge/Ht_n5ibe2spw9rNlxUkjSgffl_vq6z17Z22q-PKf3rA',
#  '/.well-known/acme-challenge/IRCaD599dGwwm7dj-Edjmz1ea7LXKIgigUcCuyny18I',
# ...

# %%
# with gzip.open("logs/tracking.log-20220306-1646506021.gz", "rb") as log_file:
#     text = log_file.read().decode('utf-8')

# text = text.replace('\n', '')

# file = open('read.txt', 'r+')
# file.write(text)

# data = json.load(file)
# data

# %%
import psycopg2
from psycopg2.extras import execute_values
from psycopg2 import Error

import pymongo

# %%
psql = {
    "user": "tmshszilbcculx",
    "password": "ee95204861668778837467651b39614a5529edd88412c1fe0a8b9a21419bf437",
    "host": "ec2-54-246-185-161.eu-west-1.compute.amazonaws.com",
    "port": "5432",
    "database": "dd83caln9k71ig"
}

# %%
try:
    sql_connection = psycopg2.connect(
        user = psql['user'],
        password = psql['password'],
        host = psql['host'],
        port = psql['port'],
        database = psql['database']
    )

    cursor = sql_connection.cursor()
    # SQL query to create a new table
    create_table_query = '''CREATE TABLE IF NOT EXISTS tracking_logs
          (log_id INT PRIMARY KEY NOT NULL,
          user_id VARCHAR(10) NULL,
          org_id TEXT NULL,
          course_id TEXT NULL,
          event_type TEXT NOT NULL,
          event_source TEXT NOT NULL,
          ip VARCHAR(15) NOT NULL,
          time TIMESTAMP NOT NULL,
          referer TEXT NULL
          );'''

    # Execute a command: this creates a new table
    cursor.execute(create_table_query)
    sql_connection.commit()
    print("Table created successfully in PostgreSQL")

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if sql_connection:
        cursor.close()
        sql_connection.close()
        print("PostgreSQL sql_connection is closed")
# Out:
# Table created successfully in PostgreSQL
# PostgreSQL sql_connection is closed

# %%
try:
    sql_connection = psycopg2.connect(
        user = psql['user'],
        password = psql['password'],
        host = psql['host'],
        port = psql['port'],
        database = psql['database']
    )

    nosql_connection = pymongo.MongoClient("mongodb://admin:8VGFjzL879y2tydc@ac-cvfgt3j-shard-00-00.c25uga7.mongodb.net:27017,ac-cvfgt3j-shard-00-01.c25uga7.mongodb.net:27017,ac-cvfgt3j-shard-00-02.c25uga7.mongodb.net:27017/?ssl=true&replicaSet=atlas-f6fwku-shard-0&authSource=admin&retryWrites=true&w=majority")
    db = nosql_connection['drc_openedx']
    collection = db['event_data']

    cursor = sql_connection.cursor()
    id = cursor.rowcount + 1

    sql_data = []
    nosql_data = []

    for log in d['logs']:
        if log['event_type'] in event_types_indoc:
            tpl = (id, f'{log["context"]["user_id"]}', f'{log["context"]["org_id"]}', f'{log["context"]["course_id"]}', f'{log["event_type"]}', f'{log["event_source"]}', f'{log["ip"]}', f'{log["time"]}', f'{log["referer"]}')
            sql_data.append(tpl)
            
            try:
                event = json.loads(log['event'])
            except TypeError:
                event = log['event']
            event['_id'] = id
            nosql_data.append(event)

            id += 1
    
    insert_query = f"""INSERT INTO tracking_logs (log_id, user_id, org_id, course_id, event_type, event_source, ip, time, referer) 
        VALUES %s"""
    execute_values(cursor, insert_query, sql_data)

    collection.insert_many(nosql_data)
    sql_connection.commit()


except (Exception, Error) as error:
    print("Error:", error)
finally:
    if sql_connection:
        cursor.close()
        sql_connection.close()
        print("PostgreSQL sql_connection is closed")
    if nosql_connection:
        nosql_connection.close()
        print("MongoDB nosql_connection is closed")
# Out:
# 393
# Error: name 'd' is not defined
# PostgreSQL sql_connection is closed
# MongoDB nosql_connection is closed
