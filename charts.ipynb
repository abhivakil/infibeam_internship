# %%
import pandas as pd
import streamlit as st

from sqlalchemy import create_engine

# %%
conn_string = "postgresql://tmshszilbcculx:ee95204861668778837467651b39614a5529edd88412c1fe0a8b9a21419bf437@ec2-54-246-185-161.eu-west-1.compute.amazonaws.com:5432/dd83caln9k71ig"

# %%
engine = create_engine(conn_string)

# %%
df = pd.read_sql('tracking_logs',con=engine)

# %%
df
# Out:
#      log_id    user_id   org_id                                   course_id  \
# 0         1  anonymous  edumaxx    course-v1:edumaxx+EAP0009+FALL_2021_2022
# 1         2  anonymous  edumaxx      course-v1:edumaxx+M0003+FALL_2021_2022
# 2         3  anonymous  edumaxx  course-v1:edumaxx+EAP0004+SUMMER_2021_2022
# 3         4  anonymous  edumaxx  course-v1:edumaxx+EAP0005+SPRING_2021_2022
# 4         5  anonymous  edumaxx      course-v1:edumaxx+M0006+FALL_2022_2023
# ..      ...        ...      ...                                         ...
# 388     389        204  edumaxx    course-v1:edumaxx+M0004+SPRING_2021_2022
# 389     390        204  edumaxx    course-v1:edumaxx+M0004+SPRING_2021_2022
# 390     391        204  edumaxx    course-v1:edumaxx+M0004+SPRING_2021_2022
# 391     392        204  edumaxx    course-v1:edumaxx+M0004+SPRING_2021_2022
# 392     393        204  edumaxx    course-v1:edumaxx+M0004+SPRING_2021_2022
#
# ...

# %%
engine.dispose()

# %%
temp_df = df[df['user_id'] != "anonymous"]

# %%
temp_df[['user_id', 'time']]
# Out:
#     user_id                time
# 7       187 2022-03-03 07:14:47
# 8       187 2022-03-03 07:14:53
# 9       187 2022-03-03 07:14:54
# 10      187 2022-03-03 07:14:57
# 11      187 2022-03-03 07:15:04
# ..      ...                 ...
# 388     204 2022-03-05 18:38:19
# 389     204 2022-03-05 18:38:25
# 390     204 2022-03-05 18:38:25
# 391     204 2022-03-05 18:38:25
# 392     204 2022-03-05 18:38:30
#
# [311 rows x 2 columns]

# %%
user_df = temp_df[['user_id', 'time']].groupby()

# %%
df[df['event_type'] == 'edx.course.enrollment.activated' | df['event_type'] == 'edx.course.enrollment.mode_changed']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\pjajo\Desktop\DRC\venv\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# File c:\Users\pjajo\Desktop\DRC\venv\lib\site-packages\pandas\core\roperator.py:56, in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...
